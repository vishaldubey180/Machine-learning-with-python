# %%
# when dataset is like below grpah it eis easy to draw boundries using logistic regression

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %%
## but if our dataset is like this we can not draw single

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %%
# we might have to split dataset again aand again to come up with decision boundries
## and this is what decision tree does for us

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %%
# to solve below problems we can use decision tree

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# # How we select ordering of features

# %%
## In above we choose degree first we might have choose deggre first also
## in that case data would be split like this

# %% [markdown]
# ![8.JPG](attachment:8.JPG)

# %% [markdown]
# ## Entropy is measure of randomness

# %%
## on left hand side we are getting pure subset, oure subset means in case of facebook all subset are green
## this mean it has very low entropy
## on right hand side there is more randomness that means entropy is high

# %% [markdown]
# ![9.JPG](attachment:9.JPG)

# %%
## So if we use company then there is high information gain
## and if degree then there is low information gain

# %% [markdown]
# ![10.JPG](attachment:10.JPG)

# %%
# Hence we should choose an approach which gives us high information gain

# %% [markdown]
# ## Gini Impurity- This is nothing but an impurity in dataset

# %% [markdown]
# ![11.JPG](attachment:11.JPG)

# %%
##when we split our dataset like this 
## at the bottom most of the dataset are red whereas one is green
## that green is immpurity
